# %%
result = 0

def add(num):
    global result
    result = result + num
    return result

print(add(3))
print(add(4))
print(add(5))
# Out:
# 3
# 7
# 12

# %%
result1 = 0
result2 = 0

def add1(num):
    global result1
    result1 = result1 + num
    return result1

def add2(num):
    global result2
    result2 = result2 + num
    return result2

print(add1(3))
print(add2(4))
print(add1(5))
print(add2(6))
# Out:
# 3
# 4
# 8
# 10

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result = self.result + num
        return self.result
    
cal1 = Calculator()
print(cal1.add(3))
print(cal1.add(4))

cal2 = Calculator()
print(cal2.add(5))
print(cal2.add(6))
# Out:
# 3
# 7
# 5
# 11

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result = self.result + num
        return self.result
    
    def sub(self, num):
        self.result -= num
        return self.result
    
print(cal2.sub(4)) # cal2는 새로만든 클래스 이전에 생성된 객체라서 업데이트가 되지 않음
# Out:
# 4.0

# %%
cal3 = Calculator()
print(cal3.add(10))
print(cal3.sub(5))
# Out:
# 10
# 5

# %%
class Calculator:
    def __init__(self):
        self.result = 0

    def add(self, num):
        self.result = self.result + num
        return self.result
    
    def sub(self, num):
        self.result -= num
        return self.result
    
    def mul(self, num):
        self.result *= num
        return self.result
    
    def div(self, num):
        if num == 0:
            return "ERROR. 0으로 나눌 수 없습니다."
        self.result = self.result / num
        return self.result
    
cal1 = Calculator()
print(cal1.add(10))
print(cal1.sub(2))
print(cal1.mul(5))
print(cal1.div(4))

print("==================================")

cal2 = Calculator()
print(cal2.add(5))
print(cal2.mul(10))
print(cal2.sub(10))
print(cal2.div(5))
print(cal2.div(0))
# Out:
# 10
# 8
# 40
# 10.0
# ==================================
# 5
# 50
# 40
# 8.0
# ERROR. 0으로 나눌 수 없습니다.

# %%
# 객체에 연산할 숫자 지정하기

class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
cal3 = FourCal()
print(type(cal3))
cal3.setdata(4, 2)
print(cal3.first)
print(cal3.second)
print(cal3.add())
# Out:
# <class '__main__.FourCal'>
# 4
# 2
# 6

# %%
class FourCal:
    def setdata(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result

    def div(self):
        result = self.first / self.second
        return result
    
cal1 = FourCal()
cal1.setdata(7, 2)
print(cal1.add())
print(cal1.sub())
print(cal1.mul())
print(cal1.div())
print(cal1.div())
# Out:
# 9
# 5
# 14
# 3.5
# 3.5

# %%
class FourCal:
    def __init__(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
cal4 = FourCal(10, 20)
print(cal4.first)
print(cal4.second)
cal4.add()
# Out:
# 10
# 20
# 30

# %%
class FourCal:
    def __init__(self, first, second):
        self.first = first
        self.second = second

    def add(self):
        result = self.first + self.second
        return result
    
    def sub(self):
        result = self.first - self.second
        return result
    
    def mul(self):
        result = self.first * self.second
        return result
    
    def div(self):
        result = self.first / self.second
        return result
    
cal5 = FourCal(7, 2)
print(cal5.add())
print(cal5.sub())
print(cal5.mul())
print(cal5.div())
# Out:
# 9
# 5
# 14
# 3.5

# %%
# 클래스의 상속

class MoreFourCal(FourCal):
    pass

# %%
cal5 = MoreFourCal(4, 2)

# %%
cal5.add()
# Out:
# 6

# %%
class MoreFourCal(FourCal):
    def pow(self):
        result = self.first ** self.second
        return result

# %%
cal6 = MoreFourCal(10, 2)
print(cal6.add())
print(cal6.pow())
# Out:
# 12
# 100

# %%
# 매서드 오버라이딩

class MoreFourCal(FourCal):
    def add(self):
        result = self.first * self.second
        return result
    
cal7 = MoreFourCal(5, 6)
print(cal7.add())
cal8 = FourCal(4, 2)
print(cal8.add())
# Out:
# 30
# 6
