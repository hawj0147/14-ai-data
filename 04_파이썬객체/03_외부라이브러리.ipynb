# %%
# Do not reinvert the wheel
from faker import Faker
fake = Faker()
fake.name()
# Out:
# 'Samantha Bennett'

# %%
fake.address()
# Out:
# '61188 Baldwin Ways Apt. 331\nSouth James, DC 31850'

# %%
test_data = [ (fake.name(), fake.address()) for _ in range(30) ]
print(test_data)
# Out:
# [('Dr. Jeffrey Sanders', '66935 John Expressway\nLake Alex, NC 11674'), ('Angela Bates', '8092 Oneal Locks\nWilliamsfurt, VI 32336'), ('Kelsey Ramirez', '1378 Anderson Cliff Apt. 882\nJonathanchester, TN 89975'), ('Andrew Ferrell', '1763 Hess Gardens Apt. 389\nKevinchester, MT 46445'), ('Gary Joyce', '5920 Rose Cove\nColemanfurt, CT 90953'), ('Elijah Lee', '2942 Roman Springs\nPort Emmaland, NY 24217'), ('Mark Martin', '50759 Wilson Stream\nNew Pamelaton, WI 11598'), ('Jason Watkins', '4865 Keller View\nJoannaport, OK 65232'), ('Rhonda Moore', 'Unit 1090 Box 3650\nDPO AE 85474'), ('Steve Walker', '98378 Hickman Streets Suite 894\nSouth Jacob, OK 77665'), ('Mr. Blake Vasquez', '580 Velazquez Plains\nNew Coltonfurt, CA 81668'), ('Timothy Turner', 'Unit 9576 Box 6192\nDPO AA 90527'), ('Scott Brown', '89034 Jessica Ranch Suite 533\nGriffinchester, VI 50840'), ('Daryl Donaldson', '29163 Michael Row Suite 242\nTranmouth, NH 26292'), ('Victoria Thompson', '7557 Theresa Via\nSalazarberg, VT 
# ...
