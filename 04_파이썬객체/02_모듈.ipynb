# %%
import module1

print(module1.add(3, 4))
print(module1.sub(5, 2))
# Out:
# 7
# 3

# %%
# from module1 import add, sub
from module1 import *   # module1 안에 있는 모든 걸 들고오겠다.

print(add(10, 20))
print(sub(10, 30))
# Out:
# 30
# -20
